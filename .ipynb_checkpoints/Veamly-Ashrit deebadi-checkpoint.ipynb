# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### comment: these are the comments made by the developers
# ### comment_date: the date when the comments where made
# ### is_merged : pull accepted or not   1- Accepted   0- Not Accepted
# ### merged_at : if Accepted ie, if is_merged is 1 then the date when it was merged
# ### request_changes: if the comments are requests for changes  1:True 0:False

# %%
data= pd.read_csv("github_comments.tsv",sep='\t',usecols=['comment','comment_date','is_merged','merged_at','request_changes'])

# %% [markdown]
# ### DATA TYPES

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 5 columns):
# comment            4001 non-null object
# comment_date       4001 non-null object
# is_merged          4001 non-null float64
# merged_at          1159 non-null object
# request_changes    4001 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 156.4+ KB

# %%
data["is_merged"].value_counts()
# Out:
# 0.0    2842
# 1.0    1159
# Name: is_merged, dtype: int64

# %% [markdown]
# ### no.of pulls accepted(is_merged ==1) and merged_at are equal 1159 hence there are no missing values

# %%
data["is_merged"].hist(bins=5, figsize=(10,8))
plt.show()

# %% [markdown]
# ### Lets check how many comments are requests for changes

# %%
data["request_changes"].value_counts(1)*100
# Out:
# 0    69.507623
# 1    30.492377
# Name: request_changes, dtype: float64

# %% [markdown]
# Out of 4001 there are only 30.5% request for change comments
# Hence most of the comments are not request comments in the dataset

# %% [markdown]
# ### Lets check the dates

# %% [markdown]
# #### Lets change the merged_at datafield to datatype and droping the NA values

# %%
merged_at=pd.to_datetime(data["merged_at"])
merged_at=merged_at.dropna()

# %%
merged_at.head()
# Out:
# 1   2017-05-25 20:34:27
# 2   2017-05-25 19:05:10
# 4   2017-05-24 04:40:42
# 5   2017-05-24 04:40:42
# 6   2017-05-24 04:40:42
# Name: merged_at, dtype: datetime64[ns]

# %%
def plotting(field):
    plt.figure(figsize=(8,6))
    sns.countplot(field.sort_values())
    loc,labels=plt.xticks()
    plt.xticks(fontsize=12,rotation=90)
    plt.show()

# %%
plotting(merged_at.dt.year)

# %% [markdown]
# #### Wow!! Most of the merges are in 2016 and 2017

# %%
plotting(merged_at.dt.quarter)

# %% [markdown]
# #### Most of the merges are in the 4 th quarter and least in 3rd quarter
# Looks like blockers are inactive during 3rd quarter
# ##### Lets see which months specifically

# %%
plotting(merged_at.dt.month)

# %% [markdown]
# ##### Interesting! Merges seem to have most acceptence during november and december.
# ##### The whole years work is paying off in the last two months and
# ##### There are very few acceptances in june and july (Time for Summer Break!!!)
# ##### Lets go deeper

# %%
plotting(merged_at.dt.day)
plotting(merged_at.dt.dayofweek)

# %% [markdown]
# ##### Looks like 3rd week of the month ,  Tuesdays and Thursdays have most accepted merges

# %% [markdown]
# ### Thats enough lets jump to comments

# %%
comments=pd.to_datetime(data["comment_date"])

# %%
comments.isnull().value_counts()
# Out:
# False    4001
# Name: comment_date, dtype: int64

# %% [markdown]
# GOOD there are no null values

# %%
plotting(comments.dt.year)

# %% [markdown]
# From merged_at is was clear that Most of the comments are in 2016 and 2017 and its verified here

# %%
plotting(comments.dt.quarter)

# %% [markdown]
# ##### There are good number of comments in first and fourth quarter

# %%
plotting(comments.dt.month)

# %% [markdown]
# #### November , December , Feb, March seems to be most commented months with July being the least

# %%
plotting(comments.dt.day)
plotting(comments.dt.dayofweek)

# %% [markdown]
# #### Sunday , Monday , Tuesday , Wednesday , Thursday  are the most commented days and there is an interesting observation 16th day of everymonth has highest comments looks like the blockers update their work/ comment every fortnight

# %%
data.head()
# Out:
#                                              comment         comment_date  \
# 0                                 @chef/maintainers   2017-05-29 10:54:23
# 1  omnibus builds are already in pain so merging ...  2017-05-25 20:34:45
# 2  @chef/client-core reviewage (lets not think to...  2017-05-25 17:21:56
# 3  This blows up 14.04 because allow-downgrades i...  2017-05-25 19:15:14
# 4  I know @lamont-granquist and @thommay  are goi...  2017-05-23 22:58:13
#
#    is_merged            merged_at  request_changes
# 0        0.0                  NaN                0
# 1        1.0  2017-05-25 20:34:27                0
# 2        1.0  2017-05-25 19:05:10                0
# 3        0.0                  NaN                1
# 4        1.0  2017-05-24 04:40:42                0

# %% [markdown]
# #### Lets see comments which are requests for changes

# %%
comments_which_are_requests_for_change= data[data["request_changes"]==1]

# %%
comments_rfc=comments_which_are_requests_for_change["comment_date"]
comments_rfc.count()
# Out:
# 1220

# %%
def plots(field):
    field=pd.to_datetime(field)
    plotting(field.dt.year)
    plotting(field.dt.quarter)
    plotting(field.dt.month)
    plotting(field.dt.day)
    plotting(field.dt.dayofweek)

# %%
comments_rfc=pd.to_datetime(comments_rfc)

# %%
plotting(comments_rfc.dt.year)

# %% [markdown]
# #### Its obvious by now that the data is mostly from 2016 and 2017 so the comments that are request for change were more in 2016 and 2017

# %%
plotting(comments_rfc.dt.quarter)

# %% [markdown]
# #### First quarter has maximum request for changes than fourth quarter

# %%
plotting(comments_rfc.dt.month)

# %% [markdown]
# March has the highest requests for changes and july has the least

# %%
plotting(comments_rfc.dt.day)

# %% [markdown]
# #### once again 16th day has highest request for change we need to understand the reasons behind it

# %%
plotting(comments_rfc.dt.dayofweek)

# %% [markdown]
# #### Sunday has the highest request for change code comments

# %% [markdown]
# ### Lets try to analyse  the comments which were merged and were requests for changes

# %%
comments_rfc.count()
# Out:
# 1220

# %%
merged_at.count()
# Out:
# 1159

# %%
data_rfc_merged=comments_which_are_requests_for_change[comments_which_are_requests_for_change["is_merged"]==1.0]

# %%
data_rfc_merged.count()
# Out:
# comment            284
# comment_date       284
# is_merged          284
# merged_at          284
# request_changes    284
# dtype: int64

# %% [markdown]
# So there are 284 comments that were requested for change and were merged

# %%
dates_erf_merged=pd.to_datetime(data_rfc_merged["merged_at"])

# %%
def plots(field):
    field=pd.to_datetime(field)
    plotting(field.dt.year)
    plotting(field.dt.quarter)
    plotting(field.dt.month)
    plotting(field.dt.day)
    plotting(field.dt.dayofweek)

# %%
plotting(dates_erf_merged.dt.year)

# %%
plotting(dates_erf_merged.dt.quarter)

# %%
plotting(dates_erf_merged.dt.month)

# %%
plotting(dates_erf_merged.dt.day)

# %%
plotting(dates_erf_merged.dt.dayofweek)

# %%
data_rfc_merged.head()
# Out:
#                                                comment         comment_date  \
# 24   This is a super frustrating bug that I'd love ...  2017-05-15 21:53:38
# 27   Looks like it was actually always broken with ...  2017-05-15 23:07:46
# 410  Looks good to me beyond the minor cosmetic iss...  2016-07-27 14:01:24
# 411                               Remove blank line.\n  2016-07-27 13:58:10
# 412  Maybe add some brief JavaDoc to the individual...  2016-07-27 13:58:48
#
#      is_merged            merged_at  request_changes
# 24         1.0  2017-05-16 08:59:50                1
# 27         1.0  2017-05-16 08:59:50                1
# 410        1.0  2016-07-27 20:59:27                1
# 411        1.0  2016-07-27 20:59:27                1
# 412        1.0  2016-07-27 20:59:27                1

# %%
val=(pd.to_datetime(data_rfc_merged["request_changes"])-dates_erf_merged )

# %%
time=(val.dt.seconds/360)

# %%
time.mean()/24
# Out:
# 3.7875595005216467

# %%
from bs4 import BeautifulSoup
example1 = BeautifulSoup(data.comment[279], 'lxml')
print (example1.get_text())
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import re
from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
partition1 = r'@[A-Za-z0-9]+'
partitiont2 = r'https?://[A-Za-z0-9./]+'
combined_partition = r'|'.join((partition1, partitiont2))
www_pat = r'www.[^ ]+'
# Out:
# Merged into master. Thank you.

# %%
def clean_tweet(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    try:
        bom_removed = souped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        bom_removed = souped
    strip = re.sub(combined_partition, '', bom_removed)
    strip = re.sub(www_pat, '', strip)
    lower_case = strip.lower()
    letters_only = re.sub("[^a-zA-Z]", " ", lower_case)
    words = [x for x  in tok.tokenize(letters_only) if len(x) > 1]
    return (" ".join(words)).strip()

# %%
data['pre_clean_len'] = [len(t) for t in data.comment]

# %%
from pprint import pprint
data_dict = {
    
    'text':{
        'type':data.comment.dtype,
        'description':'comment text'
    },
    'pre_clean_len':{
        'type':data.pre_clean_len.dtype,
        'description':'Length of the comment before cleaning'
    },
    'dataset_shape':data.shape
}
pprint(data_dict)
# Out:
# {'dataset_shape': (4001, 6),
#  'pre_clean_len': {'description': 'Length of the comment before cleaning',
#                    'type': dtype('int64')},
#  'text': {'description': 'comment text', 'type': dtype('O')}}

# %%
import re
print ("Cleaning and parsing the comments...\n")
cleaned_tweets = []
for i in range(len(data)):                                                              
    cleaned_tweets.append(clean_tweet(data['comment'][i]))
# Out:
# Cleaning and parsing the comments...
# A:\Anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://hibernate.atlassian.net/browse/HBX-1225
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# A:\Anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://lucene.apache.org/core/5_5_4/core/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# A:\Anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://hibernate.atlassian.net/browse/HV-1328" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# A:\Anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://hibernate.atlassian.net/browse/HV-1300" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
cleaned_my_data = pd.DataFrame(cleaned_tweets,columns=['text'])

cleaned_my_data.head()
# Out:
#                                                 text
# 0                                        maintainers
# 1  omnibus builds are already in pain so merging ...
# 2  client core reviewage lets not think too hard ...
# 3  this blows up because allow downgrades is not ...
# 4  know granquist and are going to be unhappy abo...

# %%
cleaned_my_data.to_

# %%
# %matplotlib inline
import nltk.data;
from gensim.models import word2vec;
from sklearn.cluster import KMeans;
from sklearn.neighbors import KDTree;
import pandas as pd;
import numpy as np;
import os;
import re;
import logging;
import sqlite3;
import time;
import sys;
import multiprocessing;
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt;
from itertools import cycle;
# Out:
# A:\Anaconda\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dashr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle');

# %%
import  gensim.models

# %%
def clean_text(all_comments):
    
    
    
    for pos in range(len(all_comments)):
    
        #Get the comment
        val = all_comments.iloc[pos]['body'];
        
        #Normalize tabs and remove newlines
        no_tabs = str(val).replace('\t', ' ').replace('\n', '');
        
        #Remove all characters except A-Z and a dot.
        alphas_only = re.sub("[^a-zA-Z\.]", " ", no_tabs);
        
        #Normalize spaces to 1
        multi_spaces = re.sub(" +", " ", alphas_only);
        
        #Strip trailing and leading spaces
        no_spaces = multi_spaces.strip();
        
        #Normalize all charachters to lowercase
        clean_text = no_spaces.lower();
        #Get sentences from the tokenizer, remove the dot in each.
        sentences = tokenizer.tokenize(clean_text);
        sentences = [re.sub("[\.]", "", sentence) for sentence in sentences];
        
        #If the text has more than one space (removing single word comments) and one character, write it to the file.
        if len(clean_text) > 0 and clean_text.count(' ') > 0:
            for sentence in sentences:
                out_file.write("%s\n" % sentence)
                print(sentence);
                
        #Simple logging. At every 50000th step,
        #print the total number of rows processed and time taken so far, and flush the file.
        if pos % 50000 == 0:
            total_time = time.time() - start;
            sys.stdout.write('Completed ' + str(round(100 * (pos / total_rows), 2)) + '% - ' + str(pos) + ' rows in time ' + str(round(total_time / 60, 0)) + ' min & ' + str(round(total_time % 60, 2)) + ' secs\r');
            out_file.flush();
            break;

# %%
neg_string = []
for t in cleaned_my_data.text:
    neg_string.append(t)
neg_string = pd.Series(neg_string).str.cat(sep=' ')

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width=1600, height=800,max_font_size=200).generate(neg_string)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
neg_string
# Out:
# 'maintainers omnibus builds are already in pain so merging to fix those client core reviewage lets not think too hard about the breakpoint resource itself just picked it because its the shortest bit of provider code out there this blows up because allow downgrades is not supported there so you ll need to figure out the first versions of ubuntu and debian that can safely support this and conditionally add the flag know granquist and are going to be unhappy about this one this is absolutely short term fix until we get choco on the windows jenkins nodes like it was before our system failure no that absolutely the right thing to do trailing comma is trolling you yolo link fixing should get added too missed adding it to the release notes in my pr might also be cool to do this for node platform version in the ohai loading we could do something like automatic platform version versionstring new automatic platform version the hack might be too much would be cool if everyone else wants to just do the fancy operator and skip the case magic yeah probably not the monkeypatching of okay the trickery is gone and chef config is no longer wrecked chefstyle needs care and feeding and now fingers crossed that this doesn some how jam the bumpbot would rather we just leave it as invalid and surface the bundler error to the user it just like you ve requested an invalid cookbook dependency should be fatal error not warning unfortunately it would be totally valid that two cookbooks want to install the same gem with the same options install from the same git repo but currently it would produce an invalid gemfile in that case edit ah nvm you mean replacing the warning with fatal error yes that makes sense we should check that the values are compatible then make sure it still an error if two cookbooks do actually request differing versions of the same gem and whatnot changed the request to fail directly whenever we would have directly conflicting requirements further checking if values are compatible might be quite complicated and is probably better done by bundler think we need to get to point where running these tests on fipsified system actually ensures fipsiness so let pass through the read want to get fips windows node and fips linux node in to the test matrix soon makes me bit twitchy should really be allow file to recieve read and call original which is much clearer that the problem is that you re working around the stub on the next line blocking other arguments and it feels like it should bit more explicitly test this setup the non fips case and explicitly mock it out to run non fips even on fips box and then mock it to fips and make sure the behavior is correct even on non fips box closes we ll want to put the ohai plugin deprecation note in there for this release though looks correct it looks like we were testing the broken behavior so existing tests just need to be changed to return systemd correctly and the use cases for systemd everything else at the same time all look right with everything defaulting to systemd except in the case where only an upstart script exists which is probably not going to work anyways but its certainly the best we could ever do and we can let the os fail in that case this is super frustrating bug that love to have fixed could have sworn that the fixed behavior was the way it worked all along yeah in we had this test ruby shared examples for an ubuntu platform with upstart update rc and systemd do before do stub service providers debian invokercd upstart systemd end it when only the sysv init script exists it returns service debian provider do allow chef platform servicehelpers to receive config for service with ntp and return initd systemd expect resolved provider to eql chef provider service systemd end so this likely broke in looks like it was actually always broken with the new solver diff db ebfc in rc travis appveyor hate you but the code looks right hey what the fundamental problem or problems you re trying to ...

# %%
import findspark
findspark.init('C:/spark')
import pyspark as ps
import warnings
from pyspark.sql import SQLContext

# %%
try:
    # create SparkContext on all CPUs available: in my case I have 7 CPUs on my laptop
    sc = ps.SparkContext('local[7]')
    sqlContext = SQLContext(sc)
    print("Just created a SparkContext")
except ValueError:
    warnings.warn("SparkContext already exists in this scope")
# Out:
# Just created a SparkContext

# %%
cleaned_my_data.to_csv('cleaned_tweet.csv',encoding='utf-8')
csv = 'cleaned_tweet.csv'
my_data = pd.read_csv(csv,index_col=0)
my_data.head()
# Out:
#                                                 text
# 0                                        maintainers
# 1  omnibus builds are already in pain so merging ...
# 2  client core reviewage lets not think too hard ...
# 3  this blows up because allow downgrades is not ...
# 4  know granquist and are going to be unhappy abo...

# %%
data = sqlContext.read.format('com.databricks.spark.csv').options(header='true', inferschema='true').load('cleaned_tweet.csv')

# %%
data.show(3)
# Out:
# +---+--------------------+
# |_c0|                text|
# +---+--------------------+
# |  0|         maintainers|
# |  1|omnibus builds ar...|
# |  2|client core revie...|
# +---+--------------------+
# only showing top 3 rows

# %%
from pyspark.ml.feature import HashingTF, IDF, Tokenizer, CountVectorizer
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline

# %%
tokenizer = Tokenizer(inputCol="text", outputCol="words")
hashtf = HashingTF(numFeatures=2**16, inputCol="words", outputCol='tf')
idf = IDF(inputCol='tf', outputCol="features", minDocFreq=5) #minDocFreq: remove sparse terms
#label_stringIdx = StringIndexer(inputCol = "target", outputCol = "label")
pipeline = Pipeline(stages=[tokenizer])

pipeline1 = Pipeline(stages=[hashtf])

pipelineFit = pipeline.fit(data)
train_df = pipelineFit.transform(data)
pipelineFit = pipeline1.fit(train_df)
train_df = pipelineFit.transform(train_df)
train_df.show(5)

col=train_df["words"]
# Out:
# +---+--------------------+--------------------+--------------------+
# |_c0|                text|               words|                  tf|
# +---+--------------------+--------------------+--------------------+
# |  0|         maintainers|       [maintainers]|(65536,[65528],[1...|
# |  1|omnibus builds ar...|[omnibus, builds,...|(65536,[3052,8436...|
# |  2|client core revie...|[client, core, re...|(65536,[2437,4492...|
# |  3|this blows up bec...|[this, blows, up,...|(65536,[3346,4633...|
# |  4|know granquist an...|[know, granquist,...|(65536,[12,4081,6...|
# +---+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
col[0]
# Out:
# Column<b'words[0]'>

# %%
for i in train_df:
    print(i[2])
# Out:
# Column<b'_c0[2]'>
# Column<b'text[2]'>
# Column<b'words[2]'>
# Column<b'tf[2]'>

# %%
from operator import add


seq = neg_string.split()   # ['Hi', 'hi', 'hi', 'bye', 'bye', 'bye', 'word', 'count']
counts=sc.parallelize(filtered_sentence)\
  .map(lambda word: (word, 1))\
  .reduceByKey(add)\
  .collect()

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

import nltk
nltk.download('punkt')
  
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(neg_string) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dashr\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
filtered_sentence
# Out:
# ['maintainers',
#  'omnibus',
#  'builds',
#  'already',
#  'pain',
#  'merging',
#  'fix',
#  'client',
#  'core',
#  'reviewage',
#  'lets',
#  'think',
#  'hard',
#  'breakpoint',
#  'resource',
#  'picked',
#  'shortest',
#  'bit',
#  'provider',
#  'code',
#  'blows',
#  'allow',
#  'downgrades',
#  'supported',
#  'need',
#  'figure',
#  'first',
#  'versions',
#  'ubuntu',
#  'debian',
#  'safely',
#  'support',
#  'conditionally',
#  'add',
#  'flag',
#  'know',
#  'granquist',
#  'going',
#  'unhappy',
#  'one',
#  'absolutely',
#  'short',
#  'term',
#  'fix',
#  'get',
#  'choco',
#  'windows',
#  'jenkins',
#  'nodes',
#  'like',
#  'system',
#  'failure',
#  'absolutely',
#  'right',
#  'thing',
#  'trailing',
#  'comma',
#  'trolling',
#  'yolo',
#  'link',
#  'fixing',
#  'get',
#  'added',
#  'missed',
#  'adding',
#  'release',
#  'notes',
#  'pr',
#  'might',
#  'also',
#  'cool',
#  'node',
#  'platform',
#  'version',
#  'ohai',
#  'loading',
#  'could',
#  'something',
#  'like',
#  'automatic',
#  'platform',
#  'version',
#  'versionstring',
#  'new',
#  'automatic',
#  'platform',
#  'version',
#  'hack',
#  'might',
#  'much',
#  'would',
#  'cool',
#  'everyone',
#  'else',
#  'wants',
#  'fancy',
#  'operator',
#  'skip',
#  'case',
#  'magic',
#  'yeah',
#  'probably',
#  'monkeypatching',
#  'okay',
#  'trickery',
#  'gone',
#  'chef',
#  'config',
#  'longer',
#  'wrecked',
#  'chefstyle',
#  'needs',
#  'care',
#  'feeding',
#  'fingers',
#  'crossed',
#  'jam',
#  'bumpbot',
#  'would',
#  'rather',
#  'leave',
#  'invalid',
#  'surface',
#  'bundler',
#  'error',
#  'user',
#  'like',
#  'requested',
#  'invalid',
#  'cookbook',
#  'dependency',
#  'fatal',
#  'error',
#  'warning',
#  'unfortunately',
#  'would',
#  'totally',
#  'valid',
#  'two',
#  'cookbooks',
#  'want',
#  'install',
#  'gem',
#  'options',
#  'install',
#  'git',
#  'repo',
#  'currently',
#  'would',
#  'produce',
#  'invalid',
#  'gemfile',
#  'case',
#  'edit',
#  'ah',
#  'nvm',
#  'mean',
#  'replacing',
#  'warning',
#  'fatal',
#  'error',
#  'yes',
#  'makes',
#  'sense',
#  'check',
#  'values',
#  'compatible',
#  'make',
#  'sure',
#  'still',
#  'error',
#  'two',
#  'cookbooks',
#  'actually',
#  'request',
#  'differing',
#  'versions',
#  'gem',
#  'whatnot',
#  'changed',
#  'request',
#  'fail',
#  'directly',
#  'whenever',
#  'would',
#  'directly',
#  'conflicting',
#  'requirements',
#  'checking',
#  'values',
#  'compatible',
#  'might',
#  'quite',
#  'complicated',
#  'probably',
#  'better',
#  'done',
#  'bundler',
#  'think',
#  'need',
#  'get',
#  'point',
#  'running',
#  'tests',
#  'fipsified',
#  'system',
#  'actually',
#  'ensures',
#  'fipsiness',
#  'let',
#  'pass',
#  'read',
#  'want',
#  'get',
#  'fips',
#  'windows',
#  'node',
#  'fips',
#  'linux',
#  'node',
#  'test',
#  'matrix',
#  'soon',
#  'makes',
#  'bit',
#  'twitchy',
#  'really',
#  'allow',
#  'file',
#  'recieve',
#  'read',
#  'call',
#  'original',
#  'much',
#  'clearer',
#  'problem',
#  'working',
#  'around',
#  'stub',
#  'next',
#  'line',
#  'blocking',
#  'arguments',
#  'feels',
#  'like',
#  'bit',
#  'explicitly',
#  'test',
#  'setup',
#  'non',
#  'fips',
#  'case',
#  'explicitly',
#  'mock',
#  'run',
#  'non',
#  'fips',
#  'even',
#  'fips',
#  'box',
#  'mock',
#  'fips',
#  'make',
#  'sure',
#  'behavior',
#  'correct',
#  'even',
#  'non',
#  'fips',
#  'box',
#  'closes',
#  'want',
#  'put',
#  'ohai',
#  'plugin',
#  'deprecation',
#  'note',
#  'release',
#  'though',
#  'looks',
#  'correct',
#  'looks',
#  'like',
#  'testing',
#  'broken',
#  'behavior',
#  'existing',
#  'tests',
#  'need',
#  'changed',
#  'return',
#  'systemd',
#  'correctly',
#  'use',
#  'cases',
#  'systemd',
#  'everything',
#  'else',
#  'time',
#  'look',
#  'right',
#  'everything',
#  'defaulting',
#  'systemd',
#  'except',
#  'case',
#  'upstart',
#  'script',
#  'exists',
#  'probably',
#  'going',
#  'work',
#  'anyways',
#  'certainly',
#  'best',
#  'could',
#  'ever',
#  'let',
#  'os',
#  'fail',
#  'case',
#  'super',
#  'frustrating',
#  'bug',
#  'love',
#  'fixed',
#  'could',
#  'sworn',
#  'fixed',
#  'behavior',
#  'way',
#  'worked',
#  'along',
#  'yeah',
#  'test',
#  'ruby',
#  'shared',
#  'examples',
#  'ubuntu',
#  'platform',
#  'upstart',
#  'update',
#  'rc',
#  'systemd',
#  'stub',
#  'service',
#  'providers',
#  'debian',
#  'invokercd',
#  'upstart',
#  'systemd',
#  'end',
#  'sysv',
#  'init',
#  'script',
#  'exists',
#  'returns',
#  'service',
#  'debian',
#  'provider',
#  'allow',
#  'chef',
#  'platform',
#  'servicehelpers',
#  'receive',
#  'config',
#  'service',
#  'ntp',
#  'return',
#  'initd',
#  'systemd',
#  'expect',
#  'resolved',
#  'provider',
#  'eql',
#  'chef',
#  'provider',
#  'service',
#  'systemd',
#  'end',
#  'likely',
#  'broke',
#  'looks',
#  'like',
#  'actually',
#  'always',
#  'broken',
#  'new',
#  'solver',
#  'diff',
#  'db',
#  'ebfc',
#  'rc',
#  'travis',
#  'appveyor',
#  'hate',
#  'code',
#  'looks',
#  'right',
#  'hey',
#  'fundamental',
#  'problem',
#  'problems',
#  'trying',
#  'solve',
#  'change',
#  'pulling',
#  'oss',
#  'docs',
#  'chef',
#  'web',
#  'docs',
#  'way',
#  'achieve',
#  'member',
#  'doc',
#  'team',
#  'strongly',
#  'favor',
#  'keeping',
#  'docs',
#  'together',
#  'feel',
#  'oss',
#  'content',
#  'split',
#  'respective',
#  'repos',
#  'would',
#  'lead',
#  'poor',
#  'user',
#  'experience',
#  'overall',
#  'scenario',
#  'content',
#  'crosses',
#  'multiple',
#  'technologies',
#  'common',
#  'ia',
#  'keeping',
#  'one',
#  'place',
#  'people',
#  'submit',
#  'doc',
#  'updates',
#  'reasons',
#  'keeping',
#  'content',
#  'one',
#  'repo',
#  'instead',
#  'conversation',
#  'pr',
#  'comments',
#  'open',
#  'discussing',
#  'zoom',
#  'folks',
#  'person',
#  'chefconf',
#  'fashion',
#  'makes',
#  'nervous',
#  'structural',
#  'thing',
#  'user',
#  'requests',
#  'depth',
#  'probably',
#  'honor',
#  'error',
#  'clearly',
#  'valid',
#  'point',
#  'use',
#  'specific',
#  'instances',
#  'uploadarchive',
#  'allowunreachable',
#  'uploadpack',
#  'allowreachablesha',
#  'inwant',
#  'enabled',
#  'git',
#  'server',
#  'allows',
#  'pulls',
#  'fetches',
#  'using',
#  'commit',
#  'id',
#  'advertised',
#  'references',
#  'type',
#  'un',
#  'shallowing',
#  'also',
#  'used',
#  'within',
#  'builds',
#  'systems',
#  'similar',
#  'conditions',
#  'would',
#  'better',
#  'explicitly',
#  'fail',
#  'condition',
#  'largest',
#  'group',
#  'consumers',
#  'probably',
#  'change',
#  'behavior',
#  'think',
#  'would',
#  'useful',
#  'warrants',
#  'addition',
#  'change',
#  'attributes',
#  'actions',
#  'resource',
#  'certainly',
#  'provide',
#  'well',
#  'let',
#  'know',
#  'either',
#  'way',
#  'opinion',
#  'code',
#  'stand',
#  'alone',
#  'cookbook',
#  'leverage',
#  'dsl',
#  'way',
#  'pr',
#  'accepted',
#  'end',
#  'world',
#  'wanted',
#  'provide',
#  'community',
#  'opportunity',
#  'functionality',
#  'available',
#  'natively',
#  'desired',
#  'thanks',
#  'sure',
#  'targeted',
#  'chef',
#  'deprecations',
#  'looks',
#  'like',
#  'missing',
#  'dco',
#  'portion',
#  'request',
#  'address',
#  'resubmit',
#  'thanks',
#  'everyone',
#  'resubmit',
#  'dco',
#  'requirements',
#  'place',
#  'thanks',
#  'force',
#  'push',
#  'branch',
#  'running',
#  'dco',
#  'sign',
#  'oooh',
#  'thanks',
#  'already',
#  'redone',
#  'pr',
#  'definetly',
#  'use',
#  'next',
#  'time',
#  'ci',
#  'failure',
#  'test',
#  'server',
#  'starting',
#  'jenkins',
#  'test',
#  'efb',
#  'jenkins',
#  'test',
#  'cc',
#  'jenkins',
#  'test',
#  'backported',
#  'fb',
#  'edef',
#  'bdff',
#  'af',
#  'cb',
#  'fea',
#  'bab',
#  'ac',
#  'abf',
#  'cacf',
#  'bc',
#  'revert',
#  'determined',
#  'fix',
#  'path',
#  'plugins',
#  'flag',
#  'deprecated',
#  'removed',
#  'need',
#  'fix',
#  'multivalued',
#  'options',
#  'need',
#  'way',
#  'thanks',
#  'taking',
#  'time',
#  'write',
#  'hope',
#  'continue',
#  'support',
#  'enhance',
#  'logstash',
#  'future',
#  'lgtm',
#  'merged',
#  'nice',
#  'see',
#  'lambdas',
#  'thanks',
#  'rather',
#  'hard',
#  'coding',
#  'additional',
#  'media',
#  'types',
#  'think',
#  'would',
#  'better',
#  'check',
#  'compatibility',
#  'xml',
#  'would',
#  'mean',
#  'standard',
#  'media',
#  'types',
#  'like',
#  'application',
#  'xml',
#  'text',
#  'xml',
#  'application',
#  'rss',
#  'xml',
#  'supported',
#  'well',
#  'custom',
#  'media',
#  'types',
#  'like',
#  'application',
#  'vnd',
#  'com',
#  'example',
#  'xml',
#  'would',
#  'like',
#  'update',
#  'pr',
#  'thanks',
#  'feedback',
#  'glad',
#  'update',
#  'pr',
#  'following',
#  'java',
#  'private',
#  'boolean',
#  'iscompatiblewithxml',
#  'mediatype',
#  'contenttype',
#  'mediatype',
#  'xmlmediatype',
#  'new',
#  'mediatype',
#  'xml',
#  'return',
#  'xmlmediatype',
#  'iscompatiblewith',
#  'contenttype',
#  'since',
#  'type',
#  'even',
#  'application',
#  'json',
#  'valid',
#  'xml',
#  'pretty',
#  'sure',
#  'misunderstood',
#  'something',
#  'process',
#  'could',
#  'provide',
#  'hint',
#  'thanks',
#  'advance',
#  'nope',
#  'misunderstood',
#  'using',
#  'check',
#  'xml',
#  'wishful',
#  'thinking',
#  'part',
#  'could',
#  'check',
#  'application',
#  'xml',
#  'text',
#  'xml',
#  'application',
#  'xml',
#  'text',
#  'xml',
#  'would',
#  'still',
#  'miss',
#  'custom',
#  'xml',
#  'media',
#  'types',
#  'well',
#  'things',
#  'like',
#  'image',
#  'svg',
#  'xml',
#  'think',
#  'robust',
#  'approach',
#  'would',
#  'treat',
#  'content',
#  'json',
#  'default',
#  'throws',
#  'exception',
#  'try',
#  'xml',
#  'throws',
#  'exception',
#  'give',
#  'thank',
#  'efforts',
#  'time',
#  'pressure',
#  'usual',
#  'release',
#  'needed',
#  'spring',
#  'boot',
#  'fixed',
#  'projects',
#  'spring',
#  'restdocs',
#  'commit',
#  'eb',
#  'bea',
#  'thanks',
#  'anyway',
#  'thank',
#  'pr',
#  'bit',
#  'please',
#  'see',
#  'changes',
#  'made',
#  'projects',
#  'spring',
#  'restdocs',
#  'commit',
#  'ae',
#  'eaf',
#  'edc',
#  'ac',
#  'projects',
#  'spring',
#  'restdocs',
#  'commit',
#  'df',
#  'fd',
#  'ffce',
#  'details',
#  'please',
#  'sign',
#  'contributor',
#  'license',
#  'agreement',
#  'repositoryid',
#  'spring',
#  'projects',
#  'spring',
#  'restdocs',
#  'pullrequestid',
#  'click',
#  'repositoryid',
#  'spring',
#  'projects',
#  'spring',
#  'restdocs',
#  'pullrequestid',
#  'manually',
#  'synchronize',
#  'status',
#  'pull',
#  'request',
#  'see',
#  'faq',
#  'frequently',
#  'asked',
#  'questions',
#  'thank',
#  'signing',
#  'contributor',
#  'license',
#  'agreement',
#  'repositoryid',
#  'spring',
#  'projects',
#  'spring',
#  'restdocs',
#  'pullrequestid',
#  'well',
#  'spotted',
#  'thanks',
#  'much',
#  'pr',
#  'thank',
#  'thank',
#  'thanks',
#  'done',
#  'thank',
#  'much',
#  'thanks',
#  'pr',
#  'resourcebundleconstraintdescriptionresolver',
#  'constructor',
#  'throw',
#  'missingresourceexception',
#  'mean',
#  'resourcebundleconstraintdescriptionresolver',
#  'constructor',
#  'much',
#  'throw',
#  'missingresourceexception',
#  'see',
#  'things',
#  'stand',
#  'constraint',
#  'encountered',
#  'description',
#  'constraintdescriptions',
#  'descriptionsforproperty',
#  'string',
#  'throw',
#  'exception',
#  'identifies',
#  'constraint',
#  'java',
#  'util',
#  'missingresourceexception',
#  'find',
#  'resource',
#  'bundle',
#  'java',
#  'util',
#  'propertyresourcebundle',
#  'key',
#  'org',
#  'hibernate',
#  'validator',
#  'constraints',
#  'time',
#  'durationmin',
#  'description',
#  'java',
#  'util',
#  'resourcebundle',
#  'getobject',
#  'resourcebundle',
#  'java',
#  'java',
#  'util',
#  'resourcebundle',
#  'getstring',
#  'resourcebundle',
#  'java',
#  'org',
#  'springframework',
#  'restdocs',
#  'constraints',
#  'resourcebundleconstraintdescriptionresolver',
#  'getdescription',
#  'resourcebundleconstraintdescriptionresolver',
#  'java',
#  'org',
#  'springframework',
#  'restdocs',
#  'constraints',
#  'resourcebundleconstraintdescriptionresolver',
#  'resolvedescription',
#  'resourcebundleconstraintdescriptionresolver',
#  'java',
#  'org',
#  'springframework',
#  'restdocs',
#  'constraints',
#  'constraintdescriptions',
#  'descriptionsforproperty',
#  'constraintdescriptions',
#  'java',
#  'think',
#  'good',
#  'thing',
#  'makes',
#  'clear',
#  'constraint',
#  'needs',
#  'described',
#  'proposed',
#  'change',
#  'undescribed',
#  'constraint',
#  'ignored',
#  'result',
#  'documentation',
#  'may',
#  'fail',
#  'describe',
#  'constraint',
#  'goes',
#  'spring',
#  'rest',
#  'docs',
#  'ethos',
#  'make',
#  'tests',
#  'fail',
#  'documentation',
#  'inaccurate',
#  'incomplete',
#  'misunderstood',
#  'intent',
#  'change',
#  'apologies',
#  'mis',
#  'summarized',
#  'issue',
#  'exceptionininitializererror',
#  'due',
#  'using',
#  'spring',
#  'rest',
#  'docs',
#  'spring',
#  'rest',
#  'docs',
#  'updated',
#  'title',
#  'description',
#  'issue',
#  'appropriately',
#  'stack',
#  'trace',
#  'java',
#  'util',
#  'missingresourceexception',
#  'find',
#  'resource',
#  'bundle',
#  'java',
#  'util',
#  'propertyresourcebundle',
#  'key',
#  'org',
#  ...]

# %%
for w in counts:
    if w[0]=='issue':
        print(w)
# Out:
# ('issue', 234)

# %%
wordcloud = WordCloud(width=1600, height=800,max_font_size=200).generate(str(filtered_sentence))
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
